# %%
import sys
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from pathlib import Path
import pandas as pd
import numpy as np
import random
import datetime
import tensorflow.keras as keras
from tensorflow.keras import layers, Input
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt
from PIL import Image
from PIL import UnidentifiedImageError
from sklearn.metrics import mean_squared_error

def initialise_session():
    K.clear_session()
    physical_devices = tf.config.list_physical_devices('GPU')
    num_physical_devices = len(physical_devices)
    print("GPUs Available: ", num_physical_devices)
    if num_physical_devices > 0:
        tf.config.set_visible_devices(physical_devices[0], 'GPU')
        tf.config.experimental.set_memory_growth(physical_devices[0], True)
        
def find_directory():
    try:
        # Check if running in a Jupyter notebook
        shell = get_ipython().__class__.__name__
        if shell == 'ZMQInteractiveShell':
            # Running in a Jupyter notebook
            directory = os.getcwd()
        else:
            # Running in a standalone Python script
            directory = Path(__file__).parent
    except NameError:
        # Running in a standalone Python script
        directory = Path(__file__).parent
    return directory
            
def build_train_image_paths(path_to_data):
    def absolute_file_paths(directory):
        for dirpath, _, filenames in os.walk(directory):
            for filename in sorted(filenames, key=lambda x: int(x.split('.')[0]) if x.split('.')[0].isdigit() else float('inf')):
                if not filename.split('.')[0].isdigit():
                    continue
                yield os.path.abspath(os.path.join(dirpath, filename))
    train_image_paths = []
    for file_path in absolute_file_paths(f"{path_to_data}/training_data/combined"):
        train_image_paths.append(file_path)
    path_indexes_to_remove = []
    for i, image_path in enumerate(train_image_paths):
        try:
            Image.open(image_path)
        except UnidentifiedImageError:
            path_indexes_to_remove.append(i)
    for index in sorted(path_indexes_to_remove, reverse=True):
        train_image_paths.pop(index)
        
    train_image_paths_and_labels = pd.DataFrame()
    train_image_paths_and_labels['image_path'] = train_image_paths

    training_norm = pd.read_csv(f"{path_to_data}/training_norm.csv")
    for image_path in train_image_paths:
        image_id = int((image_path.split('.')[0]).split('/')[-1])
        angle = training_norm.loc[training_norm['image_id'] == image_id,
                                'angle'].iloc[0]
        speed = int((training_norm.loc[training_norm['image_id'] == image_id,
                                    'speed'].iloc)[0])
        train_image_paths_and_labels.loc[train_image_paths_and_labels['image_path'] == image_path, 'angle'] = angle
        train_image_paths_and_labels.loc[train_image_paths_and_labels['image_path'] == image_path, 'speed'] = speed
    return train_image_paths_and_labels

def build_test_image_paths(path_to_data):
    image_ids = np.arange(1, 1021)
    test_image_paths = pd.DataFrame({'image_path': []})
    for image_id in image_ids:
        full_path = str(f"{path_to_data}/test_data/test_data/{str(image_id)}.png")
        test_image_paths.loc[len(test_image_paths)] = full_path
    return test_image_paths
        
def build_image_paths(directory):
    path_to_data = f"{directory}/machine-learning-in-science-ii-2023"
    train_image_paths_and_labels = build_train_image_paths(path_to_data)
    test_image_paths = build_test_image_paths(path_to_data)
    return train_image_paths_and_labels, test_image_paths

def load_files_and_paths(directory):
    if 'google.colab' in sys.modules:
        from google.colab import drive
        drive.mount('/content/drive')
        path_to_data = Path("/content/drive/MyDrive/machine-learning-in-science-ii-2023")
        train_image_paths = pd.read_csv(str(path_to_data/'training_norm_paths_googledrive.csv'))
        test_image_paths = pd.read_csv(str(path_to_data/'test_image_paths_googledrive.csv'))
    else:
        train_image_paths, test_image_paths = build_image_paths(directory)
    return train_image_paths, test_image_paths
    
def load_training_images_and_labels(image_path, speed_label, angle_label, image_shape):
    # Define a function that maps each row to an image and a pair of labels
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.resize(image, image_shape)
    speed_label = tf.cast(speed_label, tf.int32)
    angle_label = tf.cast(angle_label, tf.float32)
    return image, (speed_label, angle_label)

def augment(image_label, seed):
    image, label = image_label
    new_seed = tf.random.experimental.stateless_split(seed, num=1)[0, :]
    image = tf.image.stateless_random_brightness(
        image, max_delta=0.5, seed=new_seed)
    return image, label

def build_training_validation_and_evaluation_sets(train_image_paths, image_shape, batch_size, train_val_split):
    dataset = tf.data.Dataset.from_tensor_slices((train_image_paths['image_path'],
                                                  train_image_paths['speed'],
                                                  train_image_paths['angle']))
    dataset = dataset.map(lambda x,y,z: load_training_images_and_labels(x,y,z, image_shape)).batch(batch_size)
    num_batches = dataset.cardinality().numpy()
    dataset = dataset.shuffle(buffer_size=num_batches*batch_size)

    train_batches = int(num_batches * train_val_split[0])
    val_batches = int(num_batches * train_val_split[1])
    eval_batches = num_batches - train_batches - val_batches

    train_set = dataset.take(train_batches)
    val_set = dataset.skip(train_batches).take(val_batches)
    eval_set = dataset.skip(train_batches + val_batches)

    AUTOTUNE = tf.data.AUTOTUNE
    counter = tf.data.Dataset.counter()
    train_set = tf.data.Dataset.zip((train_set, (counter, counter)))
    train_set = train_set.map(augment, num_parallel_calls=AUTOTUNE)
    
    train_set = train_set.cache().prefetch(buffer_size=AUTOTUNE)
    val_set = val_set.cache().prefetch(buffer_size=AUTOTUNE)
    eval_set = eval_set.cache().prefetch(buffer_size=AUTOTUNE)
    
    return train_set, val_set, eval_set


class CNNs(keras.Model):
    def __init__(self, image_shape, name='CNNs'):
        super(CNNs, self).__init__(name=name)
        self.image_shape = image_shape
        
        self.CNN_speed = keras.Sequential([
            Input(shape=image_shape+(3,)),
            layers.Conv2D(32, 3,
                          padding="valid",
                          activation="relu",
                          kernel_regularizer=keras.regularizers.l2(0.1)
                          ),
            layers.Dropout(0.5),
            layers.MaxPooling2D(),
            layers.Conv2D(64, 3,
                          activation="relu",
                          kernel_regularizer=keras.regularizers.l2(0.1)
                          ),
            layers.Dropout(0.5),
            layers.MaxPooling2D(),
            layers.Conv2D(128, 3,
                          activation="relu",
                          kernel_regularizer=keras.regularizers.l2(0.1)
                          ),
            layers.Dropout(0.5),
            layers.Flatten(),
            layers.Dense(64,
                         activation="relu",
                         kernel_regularizer=keras.regularizers.l2(0.2)
                         ),
            layers.Dropout(0.5),
            layers.Dense(10)
        ], name='CNN_speed')
        
        self.CNN_angle = keras.Sequential([
            Input(shape=image_shape+(3,)),
            layers.Conv2D(32, 3, padding="valid", activation="relu"),
            layers.MaxPooling2D(),
            layers.Conv2D(64, 3, activation="relu"),
            layers.MaxPooling2D(),
            layers.Conv2D(128, 3, activation="relu"),
            layers.Flatten(),
            layers.Dense(64, activation="relu"),
            layers.Dense(10)
        ], name='CNN_angle')

        self.speed_output = keras.layers.Dense(1, activation=None, name='speed')
        self.angle_output = keras.layers.Dense(1, activation='linear', name='angle')
    
    @tf.function
    def call(self, inputs):
        x = self.CNN_speed(inputs)
        y = self.CNN_angle(inputs)
        
        speed_output = self.speed_output(x)
        angle_output = self.angle_output(y)
        return [speed_output, angle_output]


def build_model(image_shape):
    inputs = keras.layers.Input(shape=image_shape+(3,))
    [speed_output, angle_output] = CNNs(image_shape)(inputs)

    # Name outputs
    speed_output = layers.Lambda(lambda x: x, name='speed')(speed_output)
    angle_output = layers.Lambda(lambda x: x, name='angle')(angle_output)

    model = keras.models.Model(inputs=inputs, outputs=[speed_output, angle_output])
    model.summary()
    return model

def f1_score(y_true, y_pred):
    """
    Function to calculate the F1 score.
    """
    def recall(y_true, y_pred):
        """
        Recall metric.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """
        Precision metric.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    f1_score = 2 * ((precision * recall) / (precision + recall + K.epsilon()))
    return f1_score

       
class CombinedMSECallback(Callback):
    def __init__(self, eval_set):
        super().__init__()
        self.eval_set = eval_set
        self.combined_mse_history = []
        # Get the true labels for the evaluation set
        y_true_speed = np.concatenate([y[0].numpy() for x, y in eval_set], axis=0)
        y_true_angle = np.concatenate([y[1].numpy() for x, y in eval_set], axis=0)
        self.y_true = np.stack((y_true_speed, y_true_angle), axis=-1)
        self.boundary = lambda x: 1 if x > 0.5 else 0
        angles = [0.0, 0.0625, 0.125, 0.1875, 0.25, 0.3125, 0.375, 0.4375, 0.5,
                  0.5625, 0.625, 0.6875, 0.75, 0.8125, 0.875, 0.9375, 1.0]
        self.closest_angle_round = lambda x: angles[min(range(len(angles)),
                                                key = lambda i: abs(angles[i]-x))]

    def on_test_end(self, logs=None):
        # Assuming `eval_set` is the evaluation dataset returned by your function
        # and `model` is your trained model

        # Run model.predict on the evaluation set to get the predicted labels
        y_pred = model.predict(self.eval_set, verbose=0)
        y_pred = np.hstack(y_pred)
        y_pred[:, 0] = np.vectorize(self.boundary)(y_pred[:, 0])
        y_pred[:, 1] = np.vectorize(self.closest_angle_round)(y_pred[:, 1])

        # Calculate the MSE for each output separately
        mse_speed = mean_squared_error(self.y_true[:, 0], y_pred[:, 0])
        mse_angle = mean_squared_error(self.y_true[:, 1], y_pred[:, 1])

        # Combine the MSE values into a single metric
        combined_mse = (mse_speed + mse_angle) / 2
        self.combined_mse_history.append(combined_mse)
        print(f'\nEvaluation MSE: {combined_mse}')

def create_learning_rate_schedule(initial_learning_rate, final_learning_rate, total_decay_steps):
    decay_rate = (final_learning_rate / initial_learning_rate) ** (1. / total_decay_steps)
    learning_rate_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=total_decay_steps,
        decay_rate=decay_rate,
        staircase=True)
    return learning_rate_schedule
        
def train_model(model, train_set, val_set, epochs, logging, initial_learning_rate, final_learning_rate, total_decay_steps):
    learning_rate_schedule = create_learning_rate_schedule(initial_learning_rate, final_learning_rate, total_decay_steps)
    model.compile(
        optimizer = Adam(learning_rate=learning_rate_schedule),
        loss={
            'speed': keras.losses.BinaryCrossentropy(from_logits=True),
            'angle': keras.losses.MeanSquaredError()
        },
        loss_weights={
            'speed': 1,
            'angle': 1
        }
    )

    early_stopping_callback = keras.callbacks.EarlyStopping(monitor='val_loss',
                                                            start_from_epoch=1000,
                                                            restore_best_weights=True)
    combined_mse_callback = CombinedMSECallback(eval_set)

    if logging:
        log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
        tf.profiler.experimental.start(log_dir)
    
    history = model.fit(train_set,
                        epochs=epochs,
                        validation_data=val_set,
                        callbacks=[early_stopping_callback, combined_mse_callback])
    
    if logging:
        tf.profiler.experimental.stop()
        # to view log execute: "tensorboard --logdir=logs/fit/"
        
    combined_mse_history = combined_mse_callback.combined_mse_history
    return model, history, combined_mse_history

def evaluate_model(history, combined_mse_history, epochs, epoch_offset):
    lowest_evaluation_loss = str(round(min(combined_mse_history), 5))
    print(f"Lowest evaluation loss: {lowest_evaluation_loss}")
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(epochs)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    ax1.plot(epochs_range[epoch_offset:], combined_mse_history[epoch_offset:], color='g', label='Evaluation MSE')
    ax1.legend(loc='upper right')
    ax1.set_title('Evaluation Loss')
    ax2.plot(epochs_range[epoch_offset:], loss[epoch_offset:], label='Training Loss')
    ax2.plot(epochs_range[epoch_offset:], val_loss[epoch_offset:], label='Validation Loss')
    ax2.legend(loc='upper right')
    ax2.set_title('Training and Validation Loss')
    plt.show()
    return lowest_evaluation_loss
    
def load_testing_images(image_path, image_shape):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.resize(image, image_shape)
    image = tf.expand_dims(image, axis=0)
    return image

def build_test_set(test_image_paths, image_shape):
    test_set = tf.data.Dataset.from_tensor_slices(test_image_paths['image_path'])
    test_set = test_set.map(lambda x: load_testing_images(x, image_shape))
    return test_set

def threshold_predictions(predictions_df):
    boundary = lambda x: 1 if x > 0.5 else 0
    predictions_df['speed'] = predictions_df['speed'].apply(boundary)

    angles = [0.0, 0.0625, 0.125, 0.1875, 0.25, 0.3125, 0.375, 0.4375, 0.5, 0.5625,
            0.625, 0.6875, 0.75, 0.8125, 0.875, 0.9375, 1.0]
    closest_angle_round = lambda x: angles[min(range(len(angles)),
                                            key = lambda i: abs(angles[i]-x))]
    predictions_df['angle'] = predictions_df['angle'].apply(closest_angle_round)
    return predictions_df

def make_predictions(model, test_set):
    predictions = model.predict(test_set)

    speed_predictions = predictions[0]
    angle_predictions = predictions[1]

    predictions_df = pd.DataFrame()
    predictions_df['image_id'] = np.arange(1, 1021)
    predictions_df['angle'] = angle_predictions
    predictions_df['speed'] = speed_predictions

    predictions_df = threshold_predictions(predictions_df)
    return predictions_df
    
def create_submission(predictions_df, name, directory):
    submission_directory = f"{directory}/submissions"
    if not os.path.exists(submission_directory):
        os.makedirs(submission_directory)
    predictions_df.to_csv(f"{submission_directory}/submission_speedval-{name}.csv", index=False)
    
def save_tf_model(model, name, path_to_models):
    tf_model_save_path = f"{path_to_models}/tf/{name}/"
    tf.saved_model.save(model, tf_model_save_path)
    return tf_model_save_path

def save_tflite_model(model, name, path_to_models, tf_model_save_path):
    # Convert the model to tflite
    tflite_model = tf.lite.TFLiteConverter.from_saved_model(tf_model_save_path).convert()
    tflite_save_path = f"{path_to_models}/tflite"
    if not os.path.exists(tflite_save_path):
        os.makedirs(tflite_save_path)
    tflite_model_save_path = f"{tflite_save_path}/{name}"
    os.mkdir(tflite_model_save_path)
    with open(f"{tflite_model_save_path}/model.tflite", 'wb') as f:
        f.write(tflite_model)
        
def test_model(model, test_image_paths, image_shape, name, directory):
    test_decision = None
    print('Make submission? (y/n)')
    while test_decision != 'y' and test_decision != 'n':
        test_decision = input('>>> ')
        if test_decision == 'y':
            test_set = build_test_set(test_image_paths, image_shape)
            predictions_df = make_predictions(model, test_set)
            create_submission(predictions_df, name, directory)
        elif test_decision == 'n':
            break
        else:
            print("Invalid. Enter 'y' or 'n'")

def save_model(model, name, directory):
    save_decision = None
    print('Save model? (y/n)')
    while save_decision != 'y' and save_decision != 'n':
        save_decision = input('>>> ')
        if save_decision == 'y':
            path_to_models = f"{directory}/models"
            if not os.path.exists(path_to_models):
                os.makedirs(path_to_models)
            tf_model_save_path = save_tf_model(model, name, path_to_models)
            save_tflite_model(model, name, path_to_models, tf_model_save_path)
        elif save_decision == 'n':
            break
        else:
            print("Invalid. Enter 'y' or 'n'")

# %%
# --- HYPERPARAMETERS ---
batch_size = 40
epochs = 100
train_val_split = [0.7, 0.2]
image_shape = (32, 32) # (32, 32) works well
logging = False # log using tensorboard
initial_learning_rate = 0.001
final_learning_rate = 0.00001
total_decay_steps = 100
# -----------------------

# --- TRAIN ---
initialise_session()
directory = find_directory()
train_image_paths, test_image_paths = load_files_and_paths(directory)
train_set, val_set, eval_set = build_training_validation_and_evaluation_sets(train_image_paths,
                                                                   image_shape,
                                                                   batch_size,
                                                                   train_val_split)
model = build_model(image_shape)
model, history, combined_mse_history = train_model(model, train_set, val_set, epochs, logging, initial_learning_rate, final_learning_rate, total_decay_steps)
# Out:
# GPUs Available:  1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  CNNs (CNNs)                    [(None, 1),          450090      ['input_1[0][0]']
#                                  (None, 1)]
#
#  speed (Lambda)                 (None, 1)            0           ['CNNs[0][0]']
#
#  angle (Lambda)                 (None, 1)            0           ['CNNs[0][1]']
#
# ==================================================================================================
# Total params: 450,090
# Trainable params: 450,090
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 238/241 [============================>.] - ETA: 0s - loss: 146.2797 - speed_loss: 2.1345 - angle_loss: 130.1378
# Evaluation MSE: 0.131494140625
# 241/241 [==============================] - 26s 58ms/step - loss: 144.5687 - speed_loss: 2.1126 - angle_loss: 128.5233 - val_loss: 8.8459 - val_speed_loss: 0.3118 - val_angle_loss: 0.5687
# Epoch 2/100
# 239/241 [============================>.] - ETA: 0s - loss: 6.7273 - speed_loss: 0.2683 - angle_loss: 0.4542
# Evaluation MSE: 0.10051618303571429
# 241/241 [==============================] - 4s 18ms/step - loss: 6.7137 - speed_loss: 0.2679 - angle_loss: 0.4532 - val_loss: 5.0831 - val_speed_loss: 0.2038 - val_angle_loss: 0.3524
# Epoch 3/100
# 241/241 [==============================] - ETA: 0s - loss: 4.1825 - speed_loss: 0.2160 - angle_loss: 0.3156
# Evaluation MSE: 0.09124302455357142
# 241/241 [==============================] - 4s 18ms/step - loss: 4.1825 - speed_loss: 0.2160 - angle_loss: 0.3156 - val_loss: 3.3848 - val_speed_loss: 0.1799 - val_angle_loss: 0.2540
# Epoch 4/100
# 238/241 [============================>.] - ETA: 0s - loss: 2.9223 - speed_loss: 0.1985 - angle_loss: 0.2408
# Evaluation MSE: 0.09343331473214286
# 241/241 [==============================] - 4s 18ms/step - loss: 2.9161 - speed_loss: 0.1977 - angle_loss: 0.2403 - val_loss: 2.4692 - val_speed_loss: 0.1854 - val_angle_loss: 0.2001
# Epoch 5/100
# 241/241 [==============================] - ETA: 0s - loss: 2.1690 - speed_loss: 0.1858 - angle_loss: 0.1902
# Evaluation MSE: 0.07807059151785714
# 241/241 [==============================] - 6s 24ms/step - loss: 2.1690 - speed_loss: 0.1858 - angle_loss: 0.1902 - val_loss: 1.8654 - val_speed_loss: 0.1573 - val_angle_loss: 0.1633
# Epoch 6/100
# 241/241 [==============================] - ETA: 0s - loss: 1.6908 - speed_loss: 0.1761 - angle_loss: 0.1560
# Evaluation MSE: 0.06964285714285715
# 241/241 [==============================] - 6s 23ms/step - loss: 1.6908 - speed_loss: 0.1761 - angle_loss: 0.1560 - val_loss: 1.4766 - val_speed_loss: 0.1435 - val_angle_loss: 0.1390
# Epoch 7/100
# 239/241 [============================>.] - ETA: 0s - loss: 1.3672 - speed_loss: 0.1687 - angle_loss: 0.1316
# Evaluation MSE: 0.06466099330357143
# 241/241 [==============================] - 5s 19ms/step - loss: 1.3658 - speed_loss: 0.1684 - angle_loss: 0.1315 - val_loss: 1.2122 - val_speed_loss: 0.1441 - val_angle_loss: 0.1173
# Epoch 8/100
# 241/241 [==============================] - ETA: 0s - loss: 1.1331 - speed_loss: 0.1628 - angle_loss: 0.1112
# Evaluation MSE: 0.059154575892857136
# 241/241 [==============================] - 5s 21ms/step - loss: 1.1331 - speed_loss: 0.1628 - angle_loss: 0.1112 - val_loss: 1.0195 - val_speed_loss: 0.1409 - val_angle_loss: 0.1015
# Epoch 9/100
# 241/241 [==============================] - ETA: 0s - loss: 0.9654 - speed_loss: 0.1585 - angle_loss: 0.0979
# Evaluation MSE: 0.056266741071428567
# 241/241 [==============================] - 5s 19ms/step - loss: 0.9654 - speed_loss: 0.1585 - angle_loss: 0.0979 - val_loss: 0.8803 - val_speed_loss: 0.1397 - val_angle_loss: 0.0929
# Epoch 10/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.8395 - speed_loss: 0.1543 - angle_loss: 0.0886
# Evaluation MSE: 0.05187081473214286
# 241/241 [==============================] - 4s 18ms/step - loss: 0.8385 - speed_loss: 0.1540 - angle_loss: 0.0884 - val_loss: 0.7726 - val_speed_loss: 0.1369 - val_angle_loss: 0.0863
# Epoch 11/100
# 241/241 [==============================] - ETA: 0s - loss: 0.7422 - speed_loss: 0.1512 - angle_loss: 0.0813
# Evaluation MSE: 0.050856584821428574
# 241/241 [==============================] - 5s 19ms/step - loss: 0.7422 - speed_loss: 0.1512 - angle_loss: 0.0813 - val_loss: 0.6985 - val_speed_loss: 0.1379 - val_angle_loss: 0.0866
# Epoch 12/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.6664 - speed_loss: 0.1487 - angle_loss: 0.0750
# Evaluation MSE: 0.049119698660714285
# 241/241 [==============================] - 4s 18ms/step - loss: 0.6659 - speed_loss: 0.1484 - angle_loss: 0.0750 - val_loss: 0.6359 - val_speed_loss: 0.1364 - val_angle_loss: 0.0854
# Epoch 13/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.6042 - speed_loss: 0.1459 - angle_loss: 0.0692
# Evaluation MSE: 0.045615234375
# 241/241 [==============================] - 4s 18ms/step - loss: 0.6037 - speed_loss: 0.1456 - angle_loss: 0.0692 - val_loss: 0.5785 - val_speed_loss: 0.1339 - val_angle_loss: 0.0783
# Epoch 14/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.5541 - speed_loss: 0.1435 - angle_loss: 0.0644
# Evaluation MSE: 0.04473353794642858
# 241/241 [==============================] - 5s 22ms/step - loss: 0.5536 - speed_loss: 0.1433 - angle_loss: 0.0644 - val_loss: 0.5328 - val_speed_loss: 0.1334 - val_angle_loss: 0.0716
# Epoch 15/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.5139 - speed_loss: 0.1424 - angle_loss: 0.0603
# Evaluation MSE: 0.04218052455357143
# 241/241 [==============================] - 5s 20ms/step - loss: 0.5135 - speed_loss: 0.1421 - angle_loss: 0.0603 - val_loss: 0.4905 - val_speed_loss: 0.1305 - val_angle_loss: 0.0638
# Epoch 16/100
# 241/241 [==============================] - ETA: 0s - loss: 0.4787 - speed_loss: 0.1395 - angle_loss: 0.0568
# Evaluation MSE: 0.04236607142857143
# 241/241 [==============================] - 5s 19ms/step - loss: 0.4787 - speed_loss: 0.1395 - angle_loss: 0.0568 - val_loss: 0.4584 - val_speed_loss: 0.1295 - val_angle_loss: 0.0587
# Epoch 17/100
# 241/241 [==============================] - ETA: 0s - loss: 0.4499 - speed_loss: 0.1379 - angle_loss: 0.0532
# Evaluation MSE: 0.040590122767857145
# 241/241 [==============================] - 5s 19ms/step - loss: 0.4499 - speed_loss: 0.1379 - angle_loss: 0.0532 - val_loss: 0.4329 - val_speed_loss: 0.1294 - val_angle_loss: 0.0549
# Epoch 18/100
# 241/241 [==============================] - ETA: 0s - loss: 0.4253 - speed_loss: 0.1361 - angle_loss: 0.0501
# Evaluation MSE: 0.04070033482142857
# 241/241 [==============================] - 5s 19ms/step - loss: 0.4253 - speed_loss: 0.1361 - angle_loss: 0.0501 - val_loss: 0.4127 - val_speed_loss: 0.1307 - val_angle_loss: 0.0516
# Epoch 19/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.4048 - speed_loss: 0.1348 - angle_loss: 0.0475
# Evaluation MSE: 0.040114397321428574
# 241/241 [==============================] - 5s 20ms/step - loss: 0.4045 - speed_loss: 0.1346 - angle_loss: 0.0474 - val_loss: 0.3936 - val_speed_loss: 0.1292 - val_angle_loss: 0.0493
# Epoch 20/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.3863 - speed_loss: 0.1326 - angle_loss: 0.0452
# Evaluation MSE: 0.039296874999999995
# 241/241 [==============================] - 5s 21ms/step - loss: 0.3860 - speed_loss: 0.1323 - angle_loss: 0.0453 - val_loss: 0.3788 - val_speed_loss: 0.1293 - val_angle_loss: 0.0473
# Epoch 21/100
# 241/241 [==============================] - ETA: 0s - loss: 0.3707 - speed_loss: 0.1309 - angle_loss: 0.0432
# Evaluation MSE: 0.037672991071428574
# 241/241 [==============================] - 5s 19ms/step - loss: 0.3707 - speed_loss: 0.1309 - angle_loss: 0.0432 - val_loss: 0.3652 - val_speed_loss: 0.1285 - val_angle_loss: 0.0454
# Epoch 22/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.3574 - speed_loss: 0.1297 - angle_loss: 0.0413
# Evaluation MSE: 0.03716517857142857
# 241/241 [==============================] - 5s 22ms/step - loss: 0.3571 - speed_loss: 0.1294 - angle_loss: 0.0413 - val_loss: 0.3542 - val_speed_loss: 0.1283 - val_angle_loss: 0.0439
# Epoch 23/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.3458 - speed_loss: 0.1284 - angle_loss: 0.0396
# Evaluation MSE: 0.03636021205357143
# 241/241 [==============================] - 5s 21ms/step - loss: 0.3456 - speed_loss: 0.1282 - angle_loss: 0.0396 - val_loss: 0.3447 - val_speed_loss: 0.1282 - val_angle_loss: 0.0425
# Epoch 24/100
# 241/241 [==============================] - ETA: 0s - loss: 0.3356 - speed_loss: 0.1270 - angle_loss: 0.0381
# Evaluation MSE: 0.03565569196428571
# 241/241 [==============================] - 5s 20ms/step - loss: 0.3356 - speed_loss: 0.1270 - angle_loss: 0.0381 - val_loss: 0.3362 - val_speed_loss: 0.1279 - val_angle_loss: 0.0411
# Epoch 25/100
# 241/241 [==============================] - ETA: 0s - loss: 0.3269 - speed_loss: 0.1258 - angle_loss: 0.0369
# Evaluation MSE: 0.03516322544642857
# 241/241 [==============================] - 5s 19ms/step - loss: 0.3269 - speed_loss: 0.1258 - angle_loss: 0.0369 - val_loss: 0.3290 - val_speed_loss: 0.1276 - val_angle_loss: 0.0401
# Epoch 26/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.3193 - speed_loss: 0.1248 - angle_loss: 0.0356
# Evaluation MSE: 0.034623325892857146
# 241/241 [==============================] - 5s 22ms/step - loss: 0.3191 - speed_loss: 0.1247 - angle_loss: 0.0356 - val_loss: 0.3224 - val_speed_loss: 0.1271 - val_angle_loss: 0.0389
# Epoch 27/100
# 241/241 [==============================] - ETA: 0s - loss: 0.3123 - speed_loss: 0.1237 - angle_loss: 0.0344
# Evaluation MSE: 0.033843470982142854
# 241/241 [==============================] - 5s 19ms/step - loss: 0.3123 - speed_loss: 0.1237 - angle_loss: 0.0344 - val_loss: 0.3168 - val_speed_loss: 0.1268 - val_angle_loss: 0.0380
# Epoch 28/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.3065 - speed_loss: 0.1228 - angle_loss: 0.0334
# Evaluation MSE: 0.03416434151785715
# 241/241 [==============================] - 5s 21ms/step - loss: 0.3062 - speed_loss: 0.1226 - angle_loss: 0.0334 - val_loss: 0.3126 - val_speed_loss: 0.1272 - val_angle_loss: 0.0370
# Epoch 29/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.3013 - speed_loss: 0.1221 - angle_loss: 0.0324
# Evaluation MSE: 0.034591238839285714
# 241/241 [==============================] - 4s 19ms/step - loss: 0.3011 - speed_loss: 0.1219 - angle_loss: 0.0324 - val_loss: 0.3087 - val_speed_loss: 0.1274 - val_angle_loss: 0.0362
# Epoch 30/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2965 - speed_loss: 0.1211 - angle_loss: 0.0315
# Evaluation MSE: 0.03486607142857143
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2965 - speed_loss: 0.1211 - angle_loss: 0.0315 - val_loss: 0.3051 - val_speed_loss: 0.1273 - val_angle_loss: 0.0353
# Epoch 31/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2927 - speed_loss: 0.1207 - angle_loss: 0.0307
# Evaluation MSE: 0.034402901785714285
# 241/241 [==============================] - 4s 19ms/step - loss: 0.2925 - speed_loss: 0.1204 - angle_loss: 0.0308 - val_loss: 0.3016 - val_speed_loss: 0.1270 - val_angle_loss: 0.0346
# Epoch 32/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2892 - speed_loss: 0.1200 - angle_loss: 0.0301
# Evaluation MSE: 0.03382254464285714
# 241/241 [==============================] - 4s 19ms/step - loss: 0.2890 - speed_loss: 0.1199 - angle_loss: 0.0301 - val_loss: 0.2982 - val_speed_loss: 0.1262 - val_angle_loss: 0.0339
# Epoch 33/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2859 - speed_loss: 0.1193 - angle_loss: 0.0294
# Evaluation MSE: 0.03305245535714286
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2859 - speed_loss: 0.1193 - angle_loss: 0.0294 - val_loss: 0.2946 - val_speed_loss: 0.1251 - val_angle_loss: 0.0333
# Epoch 34/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2834 - speed_loss: 0.1191 - angle_loss: 0.0288
# Evaluation MSE: 0.03337472098214286
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2831 - speed_loss: 0.1188 - angle_loss: 0.0288 - val_loss: 0.2916 - val_speed_loss: 0.1241 - val_angle_loss: 0.0328
# Epoch 35/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2806 - speed_loss: 0.1183 - angle_loss: 0.0282
# Evaluation MSE: 0.032861328125
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2804 - speed_loss: 0.1182 - angle_loss: 0.0282 - val_loss: 0.2886 - val_speed_loss: 0.1229 - val_angle_loss: 0.0323
# Epoch 36/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2782 - speed_loss: 0.1178 - angle_loss: 0.0276
# Evaluation MSE: 0.03255440848214286
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2780 - speed_loss: 0.1175 - angle_loss: 0.0277 - val_loss: 0.2861 - val_speed_loss: 0.1221 - val_angle_loss: 0.0318
# Epoch 37/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2761 - speed_loss: 0.1172 - angle_loss: 0.0272
# Evaluation MSE: 0.03237444196428572
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2759 - speed_loss: 0.1170 - angle_loss: 0.0272 - val_loss: 0.2841 - val_speed_loss: 0.1213 - val_angle_loss: 0.0316
# Epoch 38/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2742 - speed_loss: 0.1168 - angle_loss: 0.0266
# Evaluation MSE: 0.03263392857142857
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2740 - speed_loss: 0.1166 - angle_loss: 0.0267 - val_loss: 0.2830 - val_speed_loss: 0.1209 - val_angle_loss: 0.0317
# Epoch 39/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2724 - speed_loss: 0.1163 - angle_loss: 0.0262
# Evaluation MSE: 0.03266322544642857
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2723 - speed_loss: 0.1161 - angle_loss: 0.0262 - val_loss: 0.2816 - val_speed_loss: 0.1205 - val_angle_loss: 0.0315
# Epoch 40/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2707 - speed_loss: 0.1157 - angle_loss: 0.0258
# Evaluation MSE: 0.03273856026785714
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2707 - speed_loss: 0.1157 - angle_loss: 0.0258 - val_loss: 0.2805 - val_speed_loss: 0.1200 - val_angle_loss: 0.0316
# Epoch 41/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2695 - speed_loss: 0.1156 - angle_loss: 0.0253
# Evaluation MSE: 0.03266183035714286
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2693 - speed_loss: 0.1154 - angle_loss: 0.0253 - val_loss: 0.2793 - val_speed_loss: 0.1196 - val_angle_loss: 0.0314
# Epoch 42/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2682 - speed_loss: 0.1153 - angle_loss: 0.0249
# Evaluation MSE: 0.032163783482142855
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2681 - speed_loss: 0.1151 - angle_loss: 0.0250 - val_loss: 0.2777 - val_speed_loss: 0.1191 - val_angle_loss: 0.0309
# Epoch 43/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2669 - speed_loss: 0.1148 - angle_loss: 0.0246
# Evaluation MSE: 0.03147042410714286
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2669 - speed_loss: 0.1148 - angle_loss: 0.0246 - val_loss: 0.2762 - val_speed_loss: 0.1186 - val_angle_loss: 0.0303
# Epoch 44/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2659 - speed_loss: 0.1145 - angle_loss: 0.0242
# Evaluation MSE: 0.03049107142857143
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2659 - speed_loss: 0.1145 - angle_loss: 0.0242 - val_loss: 0.2748 - val_speed_loss: 0.1183 - val_angle_loss: 0.0297
# Epoch 45/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2651 - speed_loss: 0.1145 - angle_loss: 0.0239
# Evaluation MSE: 0.029130859375
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2649 - speed_loss: 0.1143 - angle_loss: 0.0239 - val_loss: 0.2735 - val_speed_loss: 0.1180 - val_angle_loss: 0.0290
# Epoch 46/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2640 - speed_loss: 0.1141 - angle_loss: 0.0236
# Evaluation MSE: 0.028353794642857144
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2640 - speed_loss: 0.1141 - angle_loss: 0.0236 - val_loss: 0.2724 - val_speed_loss: 0.1179 - val_angle_loss: 0.0283
# Epoch 47/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2634 - speed_loss: 0.1140 - angle_loss: 0.0233
# Evaluation MSE: 0.02799525669642857
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2633 - speed_loss: 0.1139 - angle_loss: 0.0233 - val_loss: 0.2717 - val_speed_loss: 0.1179 - val_angle_loss: 0.0278
# Epoch 48/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2627 - speed_loss: 0.1138 - angle_loss: 0.0230
# Evaluation MSE: 0.026905691964285716
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2625 - speed_loss: 0.1137 - angle_loss: 0.0230 - val_loss: 0.2710 - val_speed_loss: 0.1179 - val_angle_loss: 0.0274
# Epoch 49/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2620 - speed_loss: 0.1136 - angle_loss: 0.0228
# Evaluation MSE: 0.026386718750000003
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2618 - speed_loss: 0.1135 - angle_loss: 0.0228 - val_loss: 0.2705 - val_speed_loss: 0.1180 - val_angle_loss: 0.0271
# Epoch 50/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2614 - speed_loss: 0.1135 - angle_loss: 0.0226
# Evaluation MSE: 0.026270926339285714
# 241/241 [==============================] - 6s 24ms/step - loss: 0.2612 - speed_loss: 0.1133 - angle_loss: 0.0226 - val_loss: 0.2701 - val_speed_loss: 0.1180 - val_angle_loss: 0.0268
# Epoch 51/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2609 - speed_loss: 0.1133 - angle_loss: 0.0224
# Evaluation MSE: 0.026201171875
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2607 - speed_loss: 0.1131 - angle_loss: 0.0224 - val_loss: 0.2697 - val_speed_loss: 0.1179 - val_angle_loss: 0.0266
# Epoch 52/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2604 - speed_loss: 0.1132 - angle_loss: 0.0221
# Evaluation MSE: 0.026021205357142856
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2602 - speed_loss: 0.1130 - angle_loss: 0.0221 - val_loss: 0.2693 - val_speed_loss: 0.1179 - val_angle_loss: 0.0264
# Epoch 53/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2599 - speed_loss: 0.1130 - angle_loss: 0.0220
# Evaluation MSE: 0.025966796875
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2598 - speed_loss: 0.1128 - angle_loss: 0.0220 - val_loss: 0.2689 - val_speed_loss: 0.1178 - val_angle_loss: 0.0262
# Epoch 54/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2595 - speed_loss: 0.1128 - angle_loss: 0.0219
# Evaluation MSE: 0.025895647321428572
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2593 - speed_loss: 0.1127 - angle_loss: 0.0219 - val_loss: 0.2685 - val_speed_loss: 0.1178 - val_angle_loss: 0.0260
# Epoch 55/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2590 - speed_loss: 0.1126 - angle_loss: 0.0217
# Evaluation MSE: 0.02582589285714286
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2590 - speed_loss: 0.1126 - angle_loss: 0.0217 - val_loss: 0.2682 - val_speed_loss: 0.1177 - val_angle_loss: 0.0259
# Epoch 56/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2586 - speed_loss: 0.1124 - angle_loss: 0.0216
# Evaluation MSE: 0.02611049107142857
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2586 - speed_loss: 0.1124 - angle_loss: 0.0216 - val_loss: 0.2678 - val_speed_loss: 0.1176 - val_angle_loss: 0.0257
# Epoch 57/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2585 - speed_loss: 0.1126 - angle_loss: 0.0215
# Evaluation MSE: 0.026113281250000002
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2583 - speed_loss: 0.1123 - angle_loss: 0.0215 - val_loss: 0.2675 - val_speed_loss: 0.1175 - val_angle_loss: 0.0256
# Epoch 58/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2580 - speed_loss: 0.1123 - angle_loss: 0.0213
# Evaluation MSE: 0.02602957589285714
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2580 - speed_loss: 0.1123 - angle_loss: 0.0213 - val_loss: 0.2672 - val_speed_loss: 0.1174 - val_angle_loss: 0.0255
# Epoch 59/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2580 - speed_loss: 0.1124 - angle_loss: 0.0212
# Evaluation MSE: 0.02669363839285714
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2578 - speed_loss: 0.1122 - angle_loss: 0.0212 - val_loss: 0.2670 - val_speed_loss: 0.1173 - val_angle_loss: 0.0253
# Epoch 60/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2577 - speed_loss: 0.1123 - angle_loss: 0.0211
# Evaluation MSE: 0.02672014508928571
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2575 - speed_loss: 0.1121 - angle_loss: 0.0211 - val_loss: 0.2668 - val_speed_loss: 0.1172 - val_angle_loss: 0.0252
# Epoch 61/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2575 - speed_loss: 0.1122 - angle_loss: 0.0210
# Evaluation MSE: 0.02672014508928571
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2573 - speed_loss: 0.1120 - angle_loss: 0.0210 - val_loss: 0.2666 - val_speed_loss: 0.1172 - val_angle_loss: 0.0252
# Epoch 62/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2573 - speed_loss: 0.1121 - angle_loss: 0.0209
# Evaluation MSE: 0.026611328125
# 241/241 [==============================] - 4s 19ms/step - loss: 0.2571 - speed_loss: 0.1120 - angle_loss: 0.0209 - val_loss: 0.2664 - val_speed_loss: 0.1171 - val_angle_loss: 0.0251
# Epoch 63/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2571 - speed_loss: 0.1121 - angle_loss: 0.0208
# Evaluation MSE: 0.026612723214285712
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2569 - speed_loss: 0.1119 - angle_loss: 0.0208 - val_loss: 0.2662 - val_speed_loss: 0.1171 - val_angle_loss: 0.0250
# Epoch 64/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2568 - speed_loss: 0.1119 - angle_loss: 0.0208
# Evaluation MSE: 0.026940569196428572
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2568 - speed_loss: 0.1119 - angle_loss: 0.0208 - val_loss: 0.2661 - val_speed_loss: 0.1171 - val_angle_loss: 0.0249
# Epoch 65/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2566 - speed_loss: 0.1119 - angle_loss: 0.0207
# Evaluation MSE: 0.026852678571428572
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2566 - speed_loss: 0.1119 - angle_loss: 0.0207 - val_loss: 0.2660 - val_speed_loss: 0.1171 - val_angle_loss: 0.0249
# Epoch 66/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2565 - speed_loss: 0.1118 - angle_loss: 0.0206
# Evaluation MSE: 0.026736886160714284
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2565 - speed_loss: 0.1118 - angle_loss: 0.0206 - val_loss: 0.2659 - val_speed_loss: 0.1170 - val_angle_loss: 0.0248
# Epoch 67/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2566 - speed_loss: 0.1120 - angle_loss: 0.0206
# Evaluation MSE: 0.027107979910714286
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2564 - speed_loss: 0.1118 - angle_loss: 0.0206 - val_loss: 0.2658 - val_speed_loss: 0.1170 - val_angle_loss: 0.0247
# Epoch 68/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2563 - speed_loss: 0.1117 - angle_loss: 0.0205
# Evaluation MSE: 0.02712890625
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2563 - speed_loss: 0.1117 - angle_loss: 0.0205 - val_loss: 0.2657 - val_speed_loss: 0.1170 - val_angle_loss: 0.0247
# Epoch 69/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2562 - speed_loss: 0.1117 - angle_loss: 0.0205
# Evaluation MSE: 0.027082868303571428
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2562 - speed_loss: 0.1117 - angle_loss: 0.0205 - val_loss: 0.2656 - val_speed_loss: 0.1170 - val_angle_loss: 0.0246
# Epoch 70/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2562 - speed_loss: 0.1118 - angle_loss: 0.0204
# Evaluation MSE: 0.027021484375
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2561 - speed_loss: 0.1117 - angle_loss: 0.0204 - val_loss: 0.2656 - val_speed_loss: 0.1170 - val_angle_loss: 0.0246
# Epoch 71/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2562 - speed_loss: 0.1118 - angle_loss: 0.0204
# Evaluation MSE: 0.027361886160714284
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2560 - speed_loss: 0.1117 - angle_loss: 0.0204 - val_loss: 0.2655 - val_speed_loss: 0.1170 - val_angle_loss: 0.0246
# Epoch 72/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2559 - speed_loss: 0.1116 - angle_loss: 0.0203
# Evaluation MSE: 0.02734095982142857
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2559 - speed_loss: 0.1116 - angle_loss: 0.0203 - val_loss: 0.2655 - val_speed_loss: 0.1170 - val_angle_loss: 0.0245
# Epoch 73/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2560 - speed_loss: 0.1118 - angle_loss: 0.0203
# Evaluation MSE: 0.027400948660714283
# 241/241 [==============================] - 6s 23ms/step - loss: 0.2559 - speed_loss: 0.1116 - angle_loss: 0.0203 - val_loss: 0.2654 - val_speed_loss: 0.1170 - val_angle_loss: 0.0245
# Epoch 74/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2560 - speed_loss: 0.1118 - angle_loss: 0.0203
# Evaluation MSE: 0.027391183035714285
# 241/241 [==============================] - 6s 25ms/step - loss: 0.2558 - speed_loss: 0.1116 - angle_loss: 0.0203 - val_loss: 0.2654 - val_speed_loss: 0.1170 - val_angle_loss: 0.0245
# Epoch 75/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2559 - speed_loss: 0.1117 - angle_loss: 0.0202
# Evaluation MSE: 0.027347935267857143
# 241/241 [==============================] - 5s 22ms/step - loss: 0.2558 - speed_loss: 0.1116 - angle_loss: 0.0203 - val_loss: 0.2654 - val_speed_loss: 0.1170 - val_angle_loss: 0.0245
# Epoch 76/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2559 - speed_loss: 0.1118 - angle_loss: 0.0202
# Evaluation MSE: 0.027374441964285713
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2557 - speed_loss: 0.1116 - angle_loss: 0.0202 - val_loss: 0.2654 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 77/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2559 - speed_loss: 0.1118 - angle_loss: 0.0202
# Evaluation MSE: 0.02733816964285714
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2557 - speed_loss: 0.1116 - angle_loss: 0.0202 - val_loss: 0.2653 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 78/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1115 - angle_loss: 0.0202
# Evaluation MSE: 0.02730189732142857
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2556 - speed_loss: 0.1115 - angle_loss: 0.0202 - val_loss: 0.2653 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 79/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2557 - speed_loss: 0.1117 - angle_loss: 0.0202
# Evaluation MSE: 0.027308872767857144
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2556 - speed_loss: 0.1115 - angle_loss: 0.0202 - val_loss: 0.2653 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 80/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2557 - speed_loss: 0.1117 - angle_loss: 0.0202
# Evaluation MSE: 0.027329799107142855
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2555 - speed_loss: 0.1115 - angle_loss: 0.0202 - val_loss: 0.2653 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 81/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2558 - speed_loss: 0.1118 - angle_loss: 0.0201
# Evaluation MSE: 0.027322823660714285
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2555 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 82/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1115 - angle_loss: 0.0201
# Evaluation MSE: 0.02799525669642857
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2555 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0244
# Epoch 83/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1117 - angle_loss: 0.0201
# Evaluation MSE: 0.02795619419642857
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2555 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 84/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2557 - speed_loss: 0.1117 - angle_loss: 0.0201
# Evaluation MSE: 0.027961774553571427
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2555 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 85/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201
# Evaluation MSE: 0.02799525669642857
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 86/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1117 - angle_loss: 0.0201
# Evaluation MSE: 0.02795619419642857
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 87/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1116 - angle_loss: 0.0201
# Evaluation MSE: 0.027964564732142858
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2652 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 88/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1116 - angle_loss: 0.0201
# Evaluation MSE: 0.027998046875
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 89/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1117 - angle_loss: 0.0201
# Evaluation MSE: 0.027945033482142858
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 90/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1117 - angle_loss: 0.0200
# Evaluation MSE: 0.027977120535714287
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2554 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 91/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1117 - angle_loss: 0.0200
# Evaluation MSE: 0.0279296875
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2553 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 92/100
# 238/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1117 - angle_loss: 0.0200
# Evaluation MSE: 0.028013392857142855
# 241/241 [==============================] - 5s 21ms/step - loss: 0.2553 - speed_loss: 0.1115 - angle_loss: 0.0201 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 93/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2553 - speed_loss: 0.1115 - angle_loss: 0.0200
# Evaluation MSE: 0.027963169642857142
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2553 - speed_loss: 0.1115 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 94/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200
# Evaluation MSE: 0.027963169642857142
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 95/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1116 - angle_loss: 0.0200
# Evaluation MSE: 0.02800083705357143
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 96/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2556 - speed_loss: 0.1117 - angle_loss: 0.0200
# Evaluation MSE: 0.027964564732142858
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 97/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1116 - angle_loss: 0.0200
# Evaluation MSE: 0.027971540178571428
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 98/100
# 240/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1116 - angle_loss: 0.0200
# Evaluation MSE: 0.028003627232142857
# 241/241 [==============================] - 5s 22ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 99/100
# 239/241 [============================>.] - ETA: 0s - loss: 0.2555 - speed_loss: 0.1117 - angle_loss: 0.0200
# Evaluation MSE: 0.02798130580357143
# 241/241 [==============================] - 4s 18ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0243
# Epoch 100/100
# 241/241 [==============================] - ETA: 0s - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200
# Evaluation MSE: 0.027972935267857144
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2553 - speed_loss: 0.1114 - angle_loss: 0.0200 - val_loss: 0.2651 - val_speed_loss: 0.1170 - val_angle_loss: 0.0242

# %%
# --- ANALYSE ---
name = evaluate_model(history, combined_mse_history, epochs, epoch_offset=3)
# Out:
# Lowest evaluation loss: 0.02583

# %%
# --- MAKE SUBMISSION ---
test_model(model, test_image_paths, image_shape, name, directory)
# Out:
# Make submission? (y/n)
# Invalid. Enter 'y' or 'n'
# 1020/1020 [==============================] - 5s 4ms/step

# %%
# --- SAVE MODEL ---
save_model(model, name, directory)
# Out:
# Save model? (y/n)
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc66004b790>, 140492221976288), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc66004b790>, 140492221976288), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d025c730>, 140489750467328), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d025c730>, 140489750467328), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d0266610>, 140489750365808), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d0266610>, 140489750365808), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d024ebb0>, 140489750365728), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d024ebb0>, 140489750365728), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc66004b790>, 140492221976288), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc66004b790>, 140492221976288), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d025c730>, 140489750467328), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d025c730>, 140489750467328), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d0266610>, 140489750365808), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d0266610>, 140489750365808), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d024ebb0>, 140489750365728), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fc6d024ebb0>, 140489750365728), {}).
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/harry/ML_GPU/DeepDreams/models/tf/0.02993/assets
# INFO:tensorflow:Assets written to: /home/harry/ML_GPU/DeepDreams/models/tf/0.02993/assets
